# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from pathlib import Path
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
file_path= Path("neo.csv")

# %%
nasa_df = pd.read_csv(file_path)
nasa_df.head()
# Out:
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
nasa_df.nunique()
# Out:
# id                    27423
# name                  27423
# est_diameter_min       1638
# est_diameter_max       1638
# relative_velocity     90828
# miss_distance         90536
# orbiting_body             1
# sentry_object             1
# absolute_magnitude     1638
# hazardous                 2
# dtype: int64

# %%
nasa_df.dtypes
# Out:
# id                      int64
# name                   object
# est_diameter_min      float64
# est_diameter_max      float64
# relative_velocity     float64
# miss_distance         float64
# orbiting_body          object
# sentry_object            bool
# absolute_magnitude    float64
# hazardous                bool
# dtype: object

# %%
nasa_df = nasa_df.drop(columns=["orbiting_body", "sentry_object"])

# %%
nasa_df = nasa_df.sample(n=250)
nasa_df
# Out:
#             id                name  est_diameter_min  est_diameter_max  \
# 25349  3653689         (2013 VE13)          0.167708          0.375008
# 60353  3117468          (2002 FT6)          0.080270          0.179490
# 49089  3703057         (2014 YC15)          0.506471          1.132505
# 23595  3621808          (2012 YD7)          0.036691          0.082043
# 19118  3366886          (2007 BC8)          0.084053          0.187949
# ...        ...                 ...               ...               ...
# 72724  2494999  494999 (2010 JU39)          0.305179          0.682402
# 5779   3690051        (2014 SM143)          0.231502          0.517654
# 73324  3843443          (2019 OU4)          0.044112          0.098637
# 43376  2016834   16834 (1997 WU22)          1.961349          4.385711
# 49091  3769412           (2017 DB)          0.010582          0.023661
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 25349       85029.469799   5.115807e+07               21.00      False
# 60353       59559.444549   6.220058e+07               22.60      False
# 49089       19124.027720   2.188316e+07               18.60      False
# 23595       30403.286362   4.332829e+07               24.30      False
# 19118       28104.683558   1.305872e+07               22.50      False
# ...                  ...            ...                 ...        ...
# 72724       78461.276228   9.006433e+06               19.70       True
# 5779        44390.114664   6.119852e+07               20.30       True
# 73324       34038.303485   2.031704e+07               23.90      False
# 43376       64789.630916   3.720539e+07               15.66      False
# 49091       27280.220366   5.866977e+07               27.00      False
#
# [250 rows x 8 columns]

# %%
nasa_df.describe()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# count  2.500000e+02        250.000000        250.000000         250.000000
# mean   1.359426e+07          0.114816          0.256737       46381.663022
# std    2.031647e+07          0.207219          0.463355       24757.634869
# min    2.003988e+06          0.002424          0.005421        8026.117701
# 25%    3.433090e+06          0.018389          0.041119       27700.088827
# 50%    3.735683e+06          0.043119          0.096417       42115.194854
# 75%    3.843159e+06          0.121494          0.271669       59958.861444
# max    5.426578e+07          1.961349          4.385711      139182.111222
#
#        miss_distance  absolute_magnitude
# count   2.500000e+02          250.000000
# mean    3.647787e+07           23.712960
# std     2.235005e+07            2.823266
# min     2.099721e+05           15.660000
# 25%     1.815987e+07           21.700000
# 50%     3.608773e+07           23.950000
# 75%     5.571188e+07           25.800000
# max     7.459490e+07           30.200000

# %%
hazardous_asteroids_df= nasa_df.loc[nasa_df['hazardous']]
hazardous_asteroids_df
# Out:
#              id                  name  est_diameter_min  est_diameter_max  \
# 62113   2065909     65909 (1998 FH12)          0.363542          0.812905
# 3974    3170231          (2003 YL118)          0.127220          0.284472
# 69043   2006239  6239 Minos (1989 QF)          0.532789          1.191352
# 32374   2359170     359170 (2009 CN5)          0.265800          0.594347
# 78343   2004450    4450 Pan (1987 SY)          0.983003          2.198062
# 69359   3714553          (2015 FT118)          0.201630          0.450858
# 25947   2206910     206910 (2004 NL8)          1.010543          2.259644
# 37482  54049354            (2020 ON3)          0.127220          0.284472
# 44506   3759716            (2016 SJ1)          0.105817          0.236614
# 23355   2144898    144898 (2004 VD17)          0.447255          1.000092
# 21865   3638629            (2013 KZ1)          0.133216          0.297879
# 57809  54143414             (2021 JY)          0.402305          0.899580
# 90426   2175706     175706 (1996 FG3)          0.545199          1.219102
# 944     3720440          (2015 KJ122)          0.105817          0.236614
# 3592    2523818    523818 (2010 SH13)          0.152952          0.342011
# 23584   2448003      448003 (2008 DE)          0.319562          0.714562
# 33873   2399774     399774 (2005 NB7)          0.515887          1.153559
# 6514    3714452          (2015 FQ117)          0.201630          0.450858
# 4097    3837522            (2018 YJ2)          0.116026          0.259442
# 87699   3441149            (2008 XQ2)          0.241299          0.539560
# 72724   2494999    494999 (2010 JU39)          0.305179          0.682402
# 5779    3690051          (2014 SM143)          0.231502          0.517654
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 62113       36908.914242   5.194654e+07               19.32       True
# 3974        34436.800620   6.651853e+07               21.60       True
# 69043       31407.077652   6.087747e+07               18.49       True
# 32374       38041.413768   2.590366e+07               20.00       True
# 78343       69060.770449   6.305680e+07               17.16       True
# 69359       42911.675282   1.795121e+07               20.60       True
# 25947       50811.681775   3.321371e+07               17.10       True
# 37482       51581.020758   7.341172e+07               21.60       True
# 44506       60269.233044   1.475328e+07               22.00       True
# 23355      115279.927028   6.894234e+07               18.87       True
# 21865       79706.183096   1.037284e+07               21.50       True
# 57809       65909.141933   6.302798e+07               19.10       True
# 90426       32251.196593   1.171584e+07               18.44       True
# 944         60092.000409   4.263838e+07               22.00       True
# 3592        45182.128787   4.810497e+07               21.20       True
# 23584       37117.101309   6.457255e+06               19.60       True
# 33873       62999.838582   5.285165e+07               18.56       True
# 6514        51512.220485   5.849863e+07               20.60       True
# 4097        82091.070661   5.205427e+07               21.80       True
# 87699       43660.666008   1.082946e+07               20.21       True
# 72724       78461.276228   9.006433e+06               19.70       True
# 5779        44390.114664   6.119852e+07               20.30       True

# %%
hazardous_graph = hazardous_asteroids_df[['hazardous','relative_velocity']]
hazardous_graph.plot(kind='bar')
plt.show()

# %%
hazardous_graph = hazardous_asteroids_df[['hazardous','absolute_magnitude']]
hazardous_graph.plot(kind='bar')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from pathlib import Path

# %%
file_path= Path("neo.csv")
nasa_df = pd.read_csv(file_path)
nasa_df.head()

# %%
nasa_df = nasa_df.drop(columns=["orbiting_body", "sentry_object"])
nasa_df.to_csv('updated_neo.csv',index=True)
