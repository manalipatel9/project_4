# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from pathlib import Path

# %%
file_path= Path("resources/neo.csv")

# %%
nasa_df = pd.read_csv(file_path)
nasa_df.head()
# Out:
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
nasa_df.nunique()
# Out:
# id                    27423
# name                  27423
# est_diameter_min       1638
# est_diameter_max       1638
# relative_velocity     90828
# miss_distance         90536
# orbiting_body             1
# sentry_object             1
# absolute_magnitude     1638
# hazardous                 2
# dtype: int64

# %%
nasa_df.dtypes
# Out:
# id                      int64
# name                   object
# est_diameter_min      float64
# est_diameter_max      float64
# relative_velocity     float64
# miss_distance         float64
# orbiting_body          object
# sentry_object            bool
# absolute_magnitude    float64
# hazardous                bool
# dtype: object

# %%
nasa_df = nasa_df.drop(columns=["orbiting_body", "sentry_object"])

# %%
nasa_df = nasa_df.sample(n=250)
nasa_df
# Out:
#              id              name  est_diameter_min  est_diameter_max  \
# 68488   3715093      (2015 FX284)          0.035039          0.078350
# 50821   3789382       (2017 VK13)          0.055533          0.124177
# 65866   3766069         (2016 YR)          0.009651          0.021579
# 58173   3483513        (2009 XT6)          0.242412          0.542051
# 59835   3647281       (2013 RK21)          0.033462          0.074824
# ...         ...               ...               ...               ...
# 88653  54246394        (2022 CL5)          0.065850          0.147245
# 43291   3607480       (2012 PP17)          0.127220          0.284472
# 34387   3715996         (2015 HJ)          0.010582          0.023661
# 67251   2235756  235756 (2004 VC)          0.494943          1.106726
# 4748    3249348       (2004 PU42)          0.012149          0.027167
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 68488       17144.544535   2.049872e+07               24.40      False
# 50821       34922.654271   1.622984e+07               23.40      False
# 65866       53611.961669   6.503229e+07               27.20      False
# 58173      132583.904724   6.256420e+07               20.20       True
# 59835       22321.020309   7.124364e+06               24.50      False
# ...                  ...            ...                 ...        ...
# 88653       57348.753428   1.217593e+07               23.03      False
# 43291       30407.860166   3.792482e+07               21.60      False
# 34387       35638.271263   3.827738e+07               27.00      False
# 67251       73449.165833   1.561760e+07               18.65       True
# 4748        41215.430207   6.744018e+06               26.70      False
#
# [250 rows x 8 columns]

# %%
nasa_df.describe()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# count  2.500000e+02        250.000000        250.000000         250.000000
# mean   1.534376e+07          0.139795          0.312590       49922.835327
# std    2.160523e+07          0.263082          0.588269       25428.768052
# min    2.007092e+06          0.000818          0.001828        6536.209102
# 25%    3.401546e+06          0.016986          0.037982       30984.438981
# 50%    3.750244e+06          0.051357          0.114837       46553.166730
# 75%    3.979157e+06          0.163526          0.365654       64049.683771
# max    5.424885e+07          2.633631          5.888979      165645.505329
#
#        miss_distance  absolute_magnitude
# count   2.500000e+02          250.000000
# mean    3.781495e+07           23.499252
# std     2.176092e+07            3.101405
# min     1.570238e+04           15.020000
# 25%     1.746774e+07           21.055000
# 50%     4.037397e+07           23.570000
# 75%     5.588663e+07           25.972500
# max     7.471578e+07           32.560000

# %%
hazardous_asteroids_df= nasa_df.loc[nasa_df['hazardous']]
hazardous_asteroids_df
# Out:
#              id                 name  est_diameter_min  est_diameter_max  \
# 58173   3483513           (2009 XT6)          0.242412          0.542051
# 12491  54049356           (2020 OP3)          0.164647          0.368163
# 14724   2152561     152561 (1991 RB)          0.391341          0.875064
# 8551   54054747            (2020 TF)          0.121494          0.271669
# 17420   2523732   523732 (2014 PG51)          0.194337          0.434550
# 1185    2068347    68347 (2001 KB67)          0.280902          0.628116
# 34386   3562866          (2011 GS60)          0.421265          0.941976
# 32245   3669253         (2014 HQ124)          0.437074          0.977327
# 59356   3893637           (2019 VF6)          0.152249          0.340440
# 35330   3825489           (2018 MG7)          0.146068          0.326618
# 31290   2140158  140158 (2001 SX169)          0.542694          1.213501
# 73687   2152754    152754 (1999 GS6)          0.380676          0.851216
# 16856   2417419   417419 (2006 KL21)          0.177237          0.396315
# 64798   2395207   395207 (2010 HQ80)          0.310853          0.695088
# 12593   2425755    425755 (2011 CP4)          0.152952          0.342011
# 74727   2164211   164211 (2004 JA27)          0.350393          0.783502
# 50469   2087684     87684 (2000 SY2)          1.608996          3.597825
# 14007   3755203          (2016 NT22)          0.334622          0.748238
# 55672   2141053    141053 (2001 XT1)          0.461907          1.032856
# 17954   2255071    255071 (2005 UH6)          0.565659          1.264853
# 80029   3125003           (2002 JE9)          0.139494          0.311918
# 8573    2483423    483423 (2000 DO1)          0.231502          0.517654
# 67251   2235756     235756 (2004 VC)          0.494943          1.106726
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 58173      132583.904724   6.256420e+07               20.20       True
# 12491       69880.748874   3.204924e+07               21.04       True
# 14724       46451.820086   3.850515e+07               19.16       True
# 8551        51196.783691   7.433866e+06               21.70       True
# 17420       64777.955777   2.106735e+07               20.68       True
# 1185        45334.703025   8.275849e+06               19.88       True
# 34386       93258.289639   6.225952e+07               19.00       True
# 32245       44039.758828   7.436804e+07               18.92       True
# 59356       63639.381438   1.447809e+07               21.21       True
# 35330       47618.025708   1.967390e+07               21.30       True
# 31290       72111.054178   3.575735e+07               18.45       True
# 73687       41725.168843   1.718400e+07               19.22       True
# 16856       13448.469764   4.144565e+07               20.88       True
# 64798       55543.368310   5.493770e+07               19.66       True
# 12593       90736.612609   2.697470e+07               21.20       True
# 74727       53841.897156   3.487415e+07               19.40       True
# 50469      100908.269226   6.070621e+07               16.09       True
# 14007      129018.428552   2.272439e+07               19.50       True
# 55672       43883.660623   2.720023e+07               18.80       True
# 17954      118967.786636   6.014063e+07               18.36       True
# 80029       48197.572167   1.164993e+07               21.40       True
# 8573       133239.622525   6.921387e+07               20.30       True
# 67251       73449.165833   1.561760e+07               18.65       True

# %%
hazardous_graph = hazardous_asteroids_df[['hazardous','relative_velocity']]
hazardous_graph.plot(kind='bar')
plt.show()

# %%
hazardous_graph = hazardous_asteroids_df[['hazardous','absolute_magnitude']]
hazardous_graph.plot(kind='bar')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from pathlib import Path

# %%
file_path= Path("resources/neo.csv")
nasa_df = pd.read_csv(file_path)
nasa_df.head()
# Out:
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
nasa_df = nasa_df.drop(columns=["orbiting_body", "sentry_object"])
nasa_df.to_csv('updated_neo.csv',index=True)
